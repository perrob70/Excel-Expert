# %% [markdown]
# ## vba (Visual Basic for Applications)

# %% [markdown]
# VBA is een groot onderwerp en voor het examen moet je de basis kennen.

# %% [markdown]
# Je vind de VBA onder Developer tools en view(beeld)

# %% [markdown]
# #### Macro opnemen

# %% [markdown]
# Je kunt een macro opnemen, benoem de macro(zonder spaties), geef een sneltoets (geen speciale tekens)<br>
# en eventueel een omschrijving<br>
# Als je de macro zo opneemt dan betreft het de cel waar je de macro voor maakt,<br>
# geef je vooraf de relatieve verwijzing, dan beweegt de macro gelijk aan de celverplaatsing <br>
# die je bij opname hebt gedaan. Verplaats je geen cel, dan zal de macro de actieve cel gebruiken

# %%
from IPython.display import Video
Video('rec.mp4')
# Out:
# <video src="rec.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('rec2.mp4')
# Out:
# <video src="rec2.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Naast de sneltoets of de menu mogelijkheden, kun je ook een knop toewijzen aan een macro

# %%
from IPython.display import Video
Video('knop.mp4')
# Out:
# <video src="knop.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('knop2.mp4')
# Out:
# <video src="knop2.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# En daarnaast kun je de macro plaatsen in de quick access toolbar en zelfs op het ribbon

# %%
from IPython.display import Video
Video('tool.mp4')
# Out:
# <video src="tool.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('tool2.mp4')
# Out:
# <video src="tool2.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# #### The VBA Editor

# %% [markdown]
# Naast het opnemen van macro's kun je ze ook in code aanpassen en zelf vanaf begin coderen<br>
# Hiervoor kun je de editor gebruiken, een compleet onafhankelijk window opent dan.<br>
# Je komt in de editor via de knop  macro's weergeven onder beeld of via developer tab macro's<br>
# In beide gevallen krijgen je popup en daar klik je op edit, ook kun je ALT F8 sneltoetsen

# %% [markdown]
# In de editor heb je vele opties, je ziet je project lijst, je ziet de excel objects(sheets en workbooks)<br>
# en je ziet je modules (macros) de opgenomen macro's staan tussen sub en end sub<br>
# onderin zijn 2 knoppen die of al je macro's uit de modules toont of 1 macro apart laat zien<br>
# met keuze vak kun je dan tussen macro's navigeren

# %%
from IPython.display import Video
Video('edit.mp4')
# Out:
# <video src="edit.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Bij de cellen op kleur maken macro moet je goed kijken uit welk kleur keuze je kiest<br>
# Bij thema kleuren heb je een beperkt keuze en daardoor sneller kans op fouten, aangezien<br>
# je niet weet hoe themakleuren becijferd zijn<br>
# Vanuit colorpallet heb je 16000000 opties<br>
# Als je in foutopsporing zit moet je de editor beeindigen om de macro uit te voeren<br>
# heb je geen fout en zit je niet in opsporing dan is de wijziging in code meteen zonder opslaan actief

# %%
from IPython.display import Video
Video('edit2.mp4')
# Out:
# <video src="edit2.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('edit3.mp4')
# Out:
# <video src="edit.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Nu gaan we verder kijken in de editor, je ziet de modules, echter zie je ook excel objecten<br>
# de blad en this workbook. Hier ga je heen voor macro's die niet door gebruikers handeling<br>
# geactiveerd moeten worden, via bv een knop of activatie in menu of sneltoets.<br>
# Ga op een van beide staan blad of this workbook, die selectie laat je verschillende declaraties zien<br>
# De workbook meer werkboek gerelateerd zoals openen, sluiten, of opslaan. Open wordt standaard getoont hier.<br>
# Bij blad gaat het meer om werkblad gereleateerde events, zoals selectie ed. Selectie wordt hier standaard geopent
# <br>
# Selectie is ook de meest gebruikte event.<br>
# Kies bovenin eerst declaraties rechts en dan this workbook links<br>
# rechts bij declaratie  kun je kiezen uit vele events.

# %%
from IPython.display import Video
Video('events.mp4')
# Out:
# <video src="events.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# We maken nu een macro aan in workbook - declaraties en kiezen voor opslaan en bij openen<br>
# wederom een msgbox. Nu is het van belang om de Macro op te slaan als een xlsm of xlsb<br>
# Tevens kun je locaties of bestanden vertrouwelijk maken in opties<br>
# In mijn werkomgeving waarschijnlijk niet mogelijk, vanwege instellingen<br>
# Op het examen is de vraag een macro te maken die start bij openen werkbook een vereiste

# %%
from IPython.display import Video
Video('events2.mp4')
# Out:
# <video src="events2.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Met Macro's kan je veel automatiseren, zoals formules plaatsen of conditional format met opname<br>
# Pas als je er met formules niet uitkomt, kun je overgaan op echt coderen in vba. <br>
# Een wijziging in je bestand na uitvoering van een macro kan niet ongedaan worden gemaakt<br>
# En dat maakt dat je dus dit moet overwegen, voor gebruik van een macro

# %%
from IPython.display import Video
Video('events3.mp4')
# Out:
# <video src="events3.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Je kunt heel eenvoudig macro code exporteren en importeren en zelf kopieeren van 1 werkboek<br>
# naar een andere werkboek. De bestandsformat is niet van belang, niet meer dan te weten welke voor<br>
# werkboek gerelateerd of werkblad gerelateerd is.

# %%
from IPython.display import Video
Video('copy.mp4')
# Out:
# <video src="copy.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Een macro zonder keyboard shortcut kun je ook nog een geven, Toon Macro's en dan opties<br>
# Dit zal niet in je code te zien zijn, integenstelling to opgenomen macro's met shortcut en <br>
# omschrijving op voorhand opgegeven, dit moet je voor netheid handmatig toevoegen in de code<br>
# Het doet echter niets af aan de werking van de macro

# %%
from IPython.display import Video
Video('ass.mp4')
# Out:
# <video src="ass.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('copyandass.mp4')
# Out:
# <video src="copyandass.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Naast de modules en excel objects (sheet  and this workbook) is er nog een derde element.<br>
# De forms(user forms), de vereiste voor het examen zijn vrij simpel.<br>
# Het aanmaken van een formulier, het plaatsen van elementen op het formulier (dit zijn dezelfde <br>
# elementen als het toevoegen op het excel blad zelf in eerdere lessen) en daarnaast<br>
# het aanpassen of beheren van de tabvolgorde (excel 2013 examen) er kan een andere simpele optie zijn<br>
# Beste is dit goed te bekijken welke opties er zijn<br>
# De opties toon je door F4 te drukken of onder beeld in het menu. De tabvolgorde staat er tussen<br>
# en heeft een volgorde van aanmaak elementen op het formulier in nummerieke volgorde, startend bij 0<br>
# Pas je deze volgorde aan dan, dan pas je de tabvolgorde aan<br>
# De userform is pas zichtbaar als je run klikt op het excel blad en normaal maak je een <br>
# knop aan op het blad om de formulier te tonen, met macro aan de knop <br>
# <br>
# ***Sub show_userform1()***<br>
# <br>
# ***Userform1.Show***<br>
# <br>
# ***End Sub***
# <br>
# <br>
#
# Meer is er niet om te weten over formulieren voor dit examen en is wellicht alleen wanneer je
# geinteresseerd bent in VBA om verdere studie van te maken. VBA krijgt concurrentie van <br>
# Java script in nieuwere excels, maar is nog lang niet overgenomen en blijft een rol spelen in de<br>
# korte termijn toekomst.

# %%
from IPython.display import Video
Video('forms.mp4')
# Out:
# <video src="forms.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('forms2.mp4')
# Out:
# <video src="forms2.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# #### User Defined functions (UDF)

# %% [markdown]
# Niet voor examen, maar handig te weten. Je kunt je eigen functies aanmaken in VBA<br>
# door code te typen beginnend met function en vba maakt een end function aan nadat je de naam van <br>
# de functie hebt getypt met (), tussen () typ je myvalue of myRange en je kunt gaan coderen.<br>
# Door op tweede regel te typen wat de functie is

# %%
from IPython.display import Video
Video('udf.mp4')
# Out:
# <video src="udf.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('udf2.mp4')
# Out:
# <video src="udf2.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Image
Image(filename='oef.png')

# %%
from IPython.display import Video
Video('oef.mp4')
# Out:
# <video src="oef.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('oefcursus.mp4')
# Out:
# <video src="oefcursus.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
